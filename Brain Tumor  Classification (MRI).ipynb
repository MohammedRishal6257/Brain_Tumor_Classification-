# %% [markdown]
# # <span style = "color:IndianRed; font-size:40px"> Brain Tumor Classification (MRI)</span>

# %% [markdown]
# ***

# %% [markdown]
# A Brain tumor is considered as one of the aggressive diseases, among children and adults. Brain tumors account for 85 to 90 percent of all primary Central Nervous System(CNS) tumors. Every year, around 11,700 people are diagnosed with a brain tumor. The 5-year survival rate for people with a cancerous brain or CNS tumor is approximately 34 percent for men and36 percent for women. Brain Tumors are classified as: Benign Tumor, Malignant Tumor, Pituitary Tumor, etc. Proper treatment, planning, and accurate diagnostics should be implemented to improve the life expectancy of the patients. The best technique to detect brain tumors is Magnetic Resonance Imaging (MRI). A huge amount of image data is generated through the scans. These images are examined by the radiologist. A manual examination can be error-prone due to the level of complexities involved in brain tumors and their properties.
# Application of automated classification techniques using Machine Learning(ML) and Artificial Intelligence(AI)has consistently shown higher accuracy than manual classification. Hence, proposing a system performing detection and classification by using Deep Learning Algorithms using ConvolutionNeural Network (CNN), Artificial Neural Network (ANN), and TransferLearning (TL) would be helpful to doctors all around the world.

# %% [markdown]
# ## Context

# %% [markdown]
# Brain Tumors are complex.  There are lot of abnormalities in the sizes and location of the brain tumor(s). This makes it really difficult for complete understanding of the nature of the tumor. Also, a professional Neurosurgeon is required for MRI analysis. Often times in developing countries the lack of skillful doctors and lack of knowledge about tumors makes it really challenging an time-consuming to generate reports from MRI. So an automated system can solve this problem.

# %% [markdown]
# ## Definition

# %% [markdown]
# To Detect and Classify Brain Tumor using CNN, and TL; as an asset of Deep Learning and to examine the tumor position(segmentation).

# %% [markdown]
# ## Let's Begin

# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np
import snowballstemmer as sns 
import matplotlib.pyplot as plt

from keras.layers import Input,Flatten,Dense,Dropout
from keras.models import Sequential

from tensorflow import keras
from tensorflow.keras.optimizers import Adam

import glob
from sklearn.utils import shuffle
from skimage.transform import resize

# %%
pwd
# Out:
# 'C:\\Users\\USER\\Documents\\Edure\\Deep Learning\\Brain_tumor'

# %% [markdown]
# ### Fetch the training Data

# %% [markdown]
# #### Use glob

# %% [markdown]
# The data contains 4 subclasses. Store all 4 in different variables

# %%
#training
Glioma_tumor = glob.glob('Training/glioma_tumor/*jpg')
Meningioma_tumor = glob.glob('Training/meningioma_tumor/*jpg')
No_tumor = glob.glob('Training/no_tumor/*jpg')
Pituitary_tumor = glob.glob('Training/pituitary_tu pg')

#testing
Glioma_tumor_test = glob.glob('Testing/glioma_tumor/*jpg')
Meningioma_tumor_test = glob.glob('Testing/meningioma_tumor/*jpg')
No_tumor_test = glob.glob('Testing/no_tumor/*jpg')
Pituitary_tumor_test = glob.glob('Testing/pituitary_tumor/*jpg')

# %% [markdown]
# ### Fetch the testing data

# %%
Glioma_tumor,Glioma_tumor_test
# Out:
# (['Training/glioma_tumor\\gg (1).jpg',
#   'Training/glioma_tumor\\gg (10).jpg',
#   'Training/glioma_tumor\\gg (11).jpg',
#   'Training/glioma_tumor\\gg (12).jpg',
#   'Training/glioma_tumor\\gg (13).jpg',
#   'Training/glioma_tumor\\gg (14).jpg',
#   'Training/glioma_tumor\\gg (15).jpg',
#   'Training/glioma_tumor\\gg (16).jpg',
#   'Training/glioma_tumor\\gg (17).jpg',
#   'Training/glioma_tumor\\gg (18).jpg',
#   'Training/glioma_tumor\\gg (19).jpg',
#   'Training/glioma_tumor\\gg (2).jpg',
#   'Training/glioma_tumor\\gg (20).jpg',
#   'Training/glioma_tumor\\gg (21).jpg',
#   'Training/glioma_tumor\\gg (22).jpg',
#   'Training/glioma_tumor\\gg (23).jpg',
#   'Training/glioma_tumor\\gg (24).jpg',
#   'Training/glioma_tumor\\gg (25).jpg',
#   'Training/glioma_tumor\\gg (26).jpg',
#   'Training/glioma_tumor\\gg (27).jpg',
#   'Training/glioma_tumor\\gg (28).jpg',
#   'Training/glioma_tumor\\gg (29).jpg',
#   'Training/glioma_tumor\\gg (3).jpg',
#   'Training/glioma_tumor\\gg (30).jpg',
#   'Training/glioma_tumor\\gg (31).jpg',
#   'Training/glioma_tumor\\gg (32).jpg',
#   'Training/glioma_tumor\\gg (33).jpg',
#   'Training/glioma_tumor\\gg (34).jpg',
#   'Training/glioma_tumor\\gg (35).jpg',
#   'Training/glioma_tumor\\gg (36).jpg',
#   'Training/glioma_tumor\\gg (37).jpg',
#   'Training/glioma_tumor\\gg (38).jpg',
#   'Training/glioma_tumor\\gg (39).jpg',
#   'Training/glioma_tumor\\gg (4).jpg',
#   'Training/glioma_tumor\\gg (40).jpg',
#   'Training/glioma_tumor\\gg (41).jpg',
#   'Training/glioma_tumor\\gg (42).jpg',
#   'Training/glioma_tumor\\gg (43).jpg',
#   'Training/glioma_tumor\\gg (44).jpg',
#   'Training/glioma_tumor\\gg (45).jpg',
#   'Training/glioma_tumor\\gg (46).jpg',
#   'Training/glioma_tumor\\gg (47).jpg',
#   'Training/glioma_tumor\\gg (48).jpg',
#   'Training/glioma_tumor\\gg (49).jpg',
#   'Training/glioma_tumor\\gg (5).jpg',
#   'Training/glioma_tumor\\gg (50).jpg',
#   'Training/glioma_tumor\\gg (51).jpg',
#   'Training/glioma_tumor\\gg (52).jpg',
#   'Training/glioma_tumor\\gg (53).jpg',
#   'Training/glioma_tumor\\gg (54).jpg',
#   'Training/glioma_tumor\\gg (55).jpg',
#   'Training/glioma_tumor\\gg (56).jpg',
#   'Training/glioma_tumor\\gg (57).jpg',
#   'Training/glioma_tumor\\gg (58).jpg',
#   'Training/glioma_tumor\\gg (59).jpg',
#   'Training/glioma_tumor\\gg (6).jpg',
#   'Training/glioma_tumor\\gg (60).jpg',
#   'Training/glioma_tumor\\gg (61).jpg',
#   'Training/glioma_tumor\\gg (62).jpg',
#   'Training/glioma_tumor\\gg (63).jpg',
#   'Training/glioma_tumor\\gg (64).jpg',
#   'Training/glioma_tumor\\gg (65).jpg',
#   'Training/glioma_tumor\\gg (66).jpg',
#   'Training/glioma_tumor\\gg (67).jpg',
#   'Training/glioma_tumor\\gg (68).jpg',
#   'Training/glioma_tumor\\gg (69).jpg',
#   'Training/glioma_tumor\\gg (7).jpg',
#   'Training/glioma_tumor\\gg (70).jpg',
#   'Training/glioma_tumor\\gg (71).jpg',
#   'Training/glioma_tumor\\gg (72).jpg',
#   'Training/glioma_tumor\\gg (73).jpg',
#   'Training/glioma_tumor\\gg (74).jpg',
#   'Training/glioma_tumor\\gg (75).jpg',
#   'Training/glioma_tumor\\gg (76).jpg',
#   'Training/glioma_tumor\\gg (77).jpg',
#   'Training/glioma_tumor\\gg (78).jpg',
#   'Training/glioma_tumor\\gg (79).jpg',
#   'Training/glioma_tumor\\gg (8).jpg',
#   'Training/glioma_tumor\\gg (80).jpg',
#   'Training/glioma_tumor\\gg (81).jpg',
#   'Training/glioma_tumor\\gg (82).jpg',
#   'Training/glioma_tumor\\gg (83).jpg',
#   'Training/glioma_tumor\\gg (84).jpg',
#   'Training/glioma_tumor\\gg (9).jpg'],
#  ['Testing/glioma_tumor\\image(1).jpg',
#   'Testing/glioma_tumor\\image(10).jpg',
#   'Testing/glioma_tumor\\image(11).jpg',
#   'Testing/glioma_tumor\\image(12).jpg',
#   'Testing/glioma_tumor\\image(13).jpg',
#   'Testing/glioma_tumor\\image(14).jpg',
#   'Testing/glioma_tumor\\image(15).jpg',
#   'Testing/glioma_tumor\\image(16).jpg',
#   'Testing/glioma_tumor\\image(17).jpg',
#   'Testing/glioma_tumor\\image(18).jpg',
#   'Testing/glioma_tumor\\image(19).jpg',
#   'Testing/glioma_tumor\\image(2).jpg',
#   'Testing/glioma_tumor\\image(20).jpg',
#   'Testing/glioma_tumor\\image(21).jpg',
#   'Testing/glioma_tumor\\image(22).jpg',
#   'Testing/glioma_tumor\\image(23).jpg',
#   'Testing/glioma_tumor\\image(24).jpg',
#   'Testing/glioma_tumor\\image(3).jpg',
#   'Testing/glioma_tumor\\image(4).jpg',
#   'Testing/glioma_tumor\\image(5).jpg',
#   'Testing/glioma_tumor\\image(6).jpg',
#   'Testing/glioma_tumor\\image(7).jpg',
#   'Testing/glioma_tumor\\image(8).jpg',
#   'Testing/glioma_tumor\\image(9).jpg'])

# %% [markdown]
# ### Find the number of images of all classes in the Training set

# %%
print(f'Number of images in Glioma_tumor is: {len(Glioma_tumor)}')
print(f'Number of images in Meningioma_tumor is: {len(Meningioma_tumor)}')
print(f'Number of images in No_tumor is: {len(No_tumor)}')
print(f'Number of images in Pituitary_tumor is: {len(Pituitary_tumor)}')
# Out:
# Number of images in Glioma_tumor is: 84
# Number of images in Meningioma_tumor is: 72
# Number of images in No_tumor is: 72
# Number of images in Pituitary_tumor is: 0

# %% [markdown]
# ### Find the number of images of all classes in the testing set

# %%
print(f'Number of images in Glioma_tumor_test is: {len(Glioma_tumor_test)}')
print(f'Number of images in Meningioma_tumor_test is: {len(Meningioma_tumor_test)}')
print(f'Number of images in No_tumor_test is: {len(No_tumor_test)}')
print(f'Number of images in Pituitary_tumor_test is: {len(Pituitary_tumor_test)}')
# Out:
# Number of images in Glioma_tumor_test is: 24
# Number of images in Meningioma_tumor_test is: 24
# Number of images in No_tumor_test is: 24
# Number of images in Pituitary_tumor_test is: 24

# %% [markdown]
# ### Store all the images inside a list and create a list with the corresponding labels

# %% [markdown]
# ### For Training set

# %%
#training_set
image = []
label = [] 
for i in Glioma_tumor:
    img = plt.imread(i)
    image.append(img)
    label.append(0)
    
for i in Meningioma_tumor:
    img = plt.imread(i)
    image.append(img)
    label.append(1)
    
for i in No_tumor:
    img = plt.imread(i)
    image.append(img)
    label.append(2)
    
for i in Pituitary_tumor:
    img = plt.imread(i)
    image.append(img)
    label.append(3)

# %% [markdown]
# ### For Testing set

# %%
#test_set
image_test = []
label_test = [] 
for i in Glioma_tumor_test:
    img = plt.imread(i)
    image_test.append(img)
    label_test.append(0)
    
for i in Meningioma_tumor_test:
    img = plt.imread(i)
    image_test.append(img)
    label_test.append(1)
    
for i in No_tumor_test:
    img = plt.imread(i)
    image_test.append(img)
    label_test.append(2)
    
for i in Pituitary_tumor_test:
    img = plt.imread(i)
    image_test.append(img)
    label_test.append(3)

# %% [markdown]
# ### Shuffle both image list and label list (In both Training and testing set)

# %% [markdown]
# #### Use shuffle function from sklearn utils

# %%
#training_set
image,label = shuffle(image,label,random_state=100)

# %%
#testing_set
image_test,label_test = shuffle(image_test,label_test)

# %% [markdown]
# ### Plot a few images from our shuffled list with its corresponding label (Either from training or test set)

# %%
#training_set 
plt.figure(figsize=(12, 8))  

for i in range (20):

    plt.subplot(4,5,i+1)
    plt.imshow(image[i])
    if label[i]==0:
        plt.title('Glioma_tumor')
    elif label[i]==1:
        plt.title('Meningioma_tumor')

    elif label[i]==1:
        plt.title('No_tumor')

    else:
        plt.title('Pituitary_tumor')

plt.tight_layout()

# %% [markdown]
# ### Check the shape of the first 10 images in our list (Either from training or test set)

# %%
for i in range(10):
    print(image[i].shape)
# Out:
# (512, 512, 3)
# (320, 497, 3)
# (442, 442, 3)
# (512, 512, 3)
# (400, 393, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (630, 630, 3)
# (512, 512, 3)

# %% [markdown]
# ### Reshape the images to 224x224( For both training and testing set)

# %% [markdown]
# Also reassign them to new variables named X_train and X_test and convert them to a numpy array

# %%
#train
xtrain = []
for i in image:
    xtrain.append(resize(i,(224,224)))

xtrain = np.array(xtrain)

# %%
xtrain.shape
# Out:
# (228, 224, 224, 3)

# %%
# testing_set
xtest = []
for i in image_test:
    xtest.append(resize(i,(224,224,3)))

xtest= np.array(xtest)

# %%
xtest.shape
# Out:
# (96, 224, 224, 3)

# %% [markdown]
# ### Create numpy arrays named y_train and y_test from our training and testing label lists we created earlier

# %%
ytrain = np.array(label)
ytest = np.array(label_test)

# %% [markdown]
# ### Plot some of our reshaped images

# %%
plt.figure(figsize=(12, 8))  

for i in range (20):

    plt.subplot(4,5,i+1)
    plt.imshow(xtrain[i])
    if label[i]==0:
        plt.title('Glioma_tumor')
    elif label[i]==1:
        plt.title('Meningioma_tumor')

    elif label[i]==1:
        plt.title('No_tumor')

    else:
        plt.title('Pituitary_tumor')
 
plt.tight_layout()

# %% [markdown]
# ### Check the shape of X_train and X_test and y_train and y_test

# %%
print(f'Shape of X_train is: {xtrain.shape}')
print(f'Shape of X_train is: {xtest.shape}')
print(f'Shape of X_train is: {ytrain.shape}')
print(f'Shape of X_train is: {ytest.shape}')
# Out:
# Shape of X_train is: (228, 224, 224, 3)
# Shape of X_train is: (96, 224, 224, 3)
# Shape of X_train is: (228,)
# Shape of X_train is: (96,)

# %% [markdown]
# ### Create a keras Sequential model with convolution layers, Flatten and  Hidden layers

# %%
from tensorflow import keras

# %%
model = keras.models.Sequential([
# first layer
    keras.layers.Conv2D(16,(3,3),activation='relu',input_shape=(224,224,3)),
    keras.layers.MaxPooling2D(2,2),
# second layer 
    keras.layers.Conv2D(32,(3,3),activation='relu'),
    keras.layers.MaxPooling2D(2,2),
# Faltten Layer 
    keras.layers.Flatten(),
# Dense Layer 
    keras.layers.Dense(64,activation='relu'),
#output layer
    keras.layers.Dense(4,activation='softmax')
])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Compile the model

# %% [markdown]
# #### Use 'sparse_categorical_crossentropy' for loss

# %%
model.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### Check the summary of our model

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 222, 222, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 111, 111, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 109, 109, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 54, 54, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 93312)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 64)                  │       5,972,032 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,977,380 (22.80 MB)
#  Trainable params: 5,977,380 (22.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model.
# Make sure to include a validation data with validation_split

# %%
model.fit(xtrain,ytrain,epochs=5,validation_split =0.2)
# Out:
# Epoch 1/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 499ms/step - accuracy: 0.3563 - loss: 2.7440 - val_accuracy: 0.1957 - val_loss: 2.5079
# Epoch 2/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 410ms/step - accuracy: 0.4299 - loss: 1.4259 - val_accuracy: 0.5000 - val_loss: 0.9963
# Epoch 3/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 412ms/step - accuracy: 0.7795 - loss: 0.8870 - val_accuracy: 0.8261 - val_loss: 0.6901
# Epoch 4/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 421ms/step - accuracy: 0.9147 - loss: 0.4766 - val_accuracy: 0.8913 - val_loss: 0.4776
# Epoch 5/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 409ms/step - accuracy: 0.9623 - loss: 0.2546 - val_accuracy: 0.9348 - val_loss: 0.2580

# %% [markdown]
# ### Evaluate the model

# %%
model.evaluate(xtrain,ytrain)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9662 - loss: 0.1671
# [0.16915348172187805, 0.9649122953414917]

# %% [markdown]
# ### Make predictions with X_test

# %%
ypred = model.predict(xtest)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step

# %%
ypred
# Out:
# array([[1.34692669e-01, 2.57690758e-01, 6.07616603e-01, 6.46291696e-08],
#        [1.37161114e-03, 1.57992402e-03, 9.97048438e-01, 3.59172414e-10],
#        [3.57752503e-03, 7.64433563e-01, 2.31988952e-01, 7.45197326e-09],
#        [5.69129537e-04, 6.59265381e-04, 9.98771608e-01, 1.27077834e-10],
#        [2.15587970e-05, 8.94422192e-05, 9.99889016e-01, 1.83465778e-13],
#        [4.96101618e-01, 2.01349750e-01, 3.02548587e-01, 1.45342263e-08],
#        [4.56107110e-02, 4.47353423e-01, 5.07028103e-01, 7.72092062e-06],
#        [5.22873029e-02, 1.72136545e-01, 7.75568247e-01, 7.90416652e-06],
#        [1.30342157e-03, 1.91402622e-02, 9.79556322e-01, 2.34851028e-09],
#        [1.23480856e-02, 1.02393888e-01, 8.85257959e-01, 2.52223984e-08],
#        [4.92225634e-03, 3.38514894e-01, 6.56562865e-01, 3.58023899e-09],
#        [1.87386979e-06, 9.26357243e-05, 9.99905467e-01, 2.04020117e-14],
#        [1.34692669e-01, 2.57690758e-01, 6.07616603e-01, 6.46291696e-08],
#        [7.29931562e-05, 3.62015853e-04, 9.99564946e-01, 7.86732918e-12],
#        [7.87203852e-03, 7.63027137e-03, 9.84497726e-01, 1.48136010e-08],
#        [1.27370586e-03, 2.73816381e-03, 9.95988071e-01, 5.07634323e-10],
#        [2.77808215e-03, 5.96995931e-04, 9.96624947e-01, 9.45379108e-10],
#        [3.56571563e-03, 8.59842077e-03, 9.87835824e-01, 5.03896613e-09],
#        [3.22992867e-03, 6.36091083e-02, 9.33161020e-01, 4.26539859e-10],
#        [2.24472402e-04, 6.52135001e-04, 9.99123394e-01, 7.63591204e-11],
#        [1.58630498e-03, 2.72347089e-02, 9.71179008e-01, 2.61079040e-11],
#        [1.21882360e-03, 1.19794265e-03, 9.97583270e-01, 3.44477946e-10],
#        [1.58534229e-01, 2.05134034e-01, 6.36329770e-01, 1.97217037e-06],
#        [4.68975119e-03, 3.41445431e-02, 9.61165667e-01, 1.48410066e-08],
#        [1.34692669e-01, 2.57690758e-01, 6.07616603e-01, 6.46291696e-08],
#        [5.97402779e-03, 1.93638839e-02, 9.74662006e-01, 6.34878319e-08],
#        [4.13335487e-02, 7.83927441e-02, 8.80273640e-01, 4.38453398e-08],
#        [1.23480856e-02, 1.02393888e-01, 8.85257959e-01, 2.52223984e-08],
#        [1.90803199e-03, 7.13266106e-03, 9.90959287e-01, 2.16688861e-10],
#        [5.14278002e-03, 5.16261458e-02, 9.43231106e-01, 5.79051962e-09],
#        [3.28468084e-02, 6.45889640e-02, 9.02564108e-01, 2.09528448e-08],
#        [1.23480875e-02, 1.02393851e-01, 8.85258079e-01, 2.52224019e-08],
#        [1.03404718e-05, 2.07706558e-04, 9.99781907e-01, 6.12878455e-13],
#        [2.06419285e-02, 3.19021754e-02, 9.47455943e-01, 2.21597283e-08],
#        [4.84671764e-04, 3.89787857e-03, 9.95617390e-01, 1.72086867e-09],
#        [7.83869624e-03, 4.47835959e-02, 9.47377682e-01, 3.29151320e-08],
#        [1.73415646e-01, 1.87068433e-01, 6.39487207e-01, 2.87374060e-05],
#        [1.29357323e-01, 2.80425847e-01, 5.90216577e-01, 1.87896546e-07],
#        [4.81877849e-03, 1.96368173e-02, 9.75544453e-01, 1.29073552e-08],
#        [1.09683461e-02, 1.15290862e-02, 9.77502525e-01, 4.94953523e-10],
#        [7.19242598e-06, 2.48786760e-04, 9.99743998e-01, 3.59933818e-15],
#        [2.10702401e-02, 7.75171965e-02, 9.01410699e-01, 1.80058657e-06],
#        [2.85859365e-04, 1.25715532e-03, 9.98456955e-01, 1.64742511e-10],
#        [3.21488790e-02, 3.28271240e-01, 6.39578640e-01, 1.24796475e-06],
#        [5.89674491e-05, 4.84089484e-04, 9.99456942e-01, 3.08548434e-13],
#        [2.05611914e-01, 5.06627150e-02, 7.43725300e-01, 1.49186563e-09],
#        [1.28846569e-03, 5.51152416e-03, 9.93200004e-01, 6.65793046e-11],
#        [6.09227642e-02, 1.05562344e-01, 8.33512843e-01, 2.03823561e-06],
#        [3.83117534e-02, 2.79676586e-01, 6.82010293e-01, 1.33626020e-06],
#        [7.39210445e-05, 8.24790797e-04, 9.99101281e-01, 2.08382790e-11],
#        [1.93034101e-03, 1.73472986e-02, 9.80722368e-01, 6.99518610e-10],
#        [3.59061989e-03, 4.37463960e-03, 9.92034733e-01, 1.78986816e-08],
#        [1.30342157e-03, 1.91402622e-02, 9.79556322e-01, 2.34851028e-09],
#        [6.46421686e-04, 4.92570316e-03, 9.94427919e-01, 8.91324015e-10],
#        [6.02022701e-05, 2.50233625e-05, 9.99914765e-01, 1.99710718e-13],
#        [1.37160975e-03, 1.57992332e-03, 9.97048438e-01, 3.59173108e-10],
#        [5.66483289e-02, 3.74273062e-02, 9.05924320e-01, 7.80485294e-08],
#        [5.72395697e-03, 7.17848167e-02, 9.22491193e-01, 9.13786167e-08],
#        [1.59943998e-02, 3.00102886e-02, 9.53995228e-01, 4.68775418e-08],
#        [2.35066473e-01, 3.36759418e-01, 4.27704424e-01, 4.69634047e-04],
#        [5.42997092e-04, 2.19100341e-03, 9.97266054e-01, 1.39984149e-10],
#        [2.93549556e-06, 3.15501893e-05, 9.99965429e-01, 1.64555174e-14],
#        [9.38197449e-02, 2.63405573e-02, 8.79839599e-01, 1.67015770e-08],
#        [1.36037290e-01, 2.63277531e-01, 6.00685060e-01, 6.80381262e-08],
#        [8.59022781e-04, 2.52244039e-03, 9.96618509e-01, 6.57789934e-10],
#        [2.79956323e-04, 5.68560371e-03, 9.94034350e-01, 2.54103599e-10],
#        [1.35564469e-02, 1.07411616e-01, 8.79031003e-01, 9.08234313e-07],
#        [2.25886197e-05, 1.40010336e-04, 9.99837279e-01, 8.03555085e-14],
#        [4.04784696e-05, 2.18957270e-04, 9.99740541e-01, 2.13241902e-12],
#        [5.57508506e-03, 6.22490374e-03, 9.88199949e-01, 7.72352280e-08],
#        [1.83844122e-06, 1.63013374e-05, 9.99981880e-01, 4.58662708e-15],
#        [1.25393865e-03, 4.50217025e-03, 9.94243801e-01, 3.69079128e-10],
#        [1.06072523e-01, 1.95048541e-01, 6.98876858e-01, 2.08875213e-06],
#        [7.76294991e-03, 3.05593964e-02, 9.61677611e-01, 4.76448392e-08],
#        [9.53965864e-05, 3.60749546e-04, 9.99543726e-01, 7.31400530e-12],
#        [6.18585991e-03, 4.21946608e-02, 9.51619446e-01, 6.83238605e-11],
#        [1.01193925e-02, 5.26998416e-02, 9.37180519e-01, 1.91697879e-07],
#        [3.59061989e-03, 4.37463960e-03, 9.92034733e-01, 1.78986816e-08],
#        [2.48485185e-06, 1.78407026e-05, 9.99979615e-01, 8.74633357e-16],
#        [2.86919560e-04, 9.03905078e-04, 9.98809099e-01, 2.85774893e-11],
#        [1.04773361e-02, 1.19341239e-02, 9.77588415e-01, 8.93291983e-08],
#        [2.79987138e-03, 1.10616563e-02, 9.86138523e-01, 4.12890921e-09],
#        [1.06127700e-03, 2.82366807e-03, 9.96115088e-01, 4.48083071e-10],
#        [6.18585991e-03, 4.21946608e-02, 9.51619446e-01, 6.83238605e-11],
#        [2.95380186e-02, 1.07358031e-01, 8.63103986e-01, 1.61873341e-08],
#        [1.46200210e-01, 3.58303450e-02, 8.17969441e-01, 9.94391680e-10],
#        [4.41190787e-04, 8.86306632e-03, 9.90695715e-01, 5.79138313e-14],
#        [4.75008710e-04, 5.52892871e-03, 9.93996024e-01, 1.92176963e-09],
#        [6.02022119e-05, 2.50233625e-05, 9.99914765e-01, 1.99710718e-13],
#        [2.15016436e-02, 7.05626011e-02, 9.07934725e-01, 1.06606751e-06],
#        [1.17052614e-03, 5.27828326e-03, 9.93551135e-01, 6.58464216e-09],
#        [1.21459952e-05, 8.22579968e-05, 9.99905586e-01, 1.44991929e-13],
#        [1.34216435e-07, 6.98690519e-06, 9.99992847e-01, 9.85762386e-18],
#        [4.56107110e-02, 4.47353423e-01, 5.07028103e-01, 7.72092062e-06],
#        [3.77808884e-02, 4.98901397e-01, 4.63317633e-01, 3.01300679e-10],
#        [1.27370644e-03, 2.73816381e-03, 9.95988071e-01, 5.07634323e-10]],
#       dtype=float32)

# %% [markdown]
# ### Use np.argmax to fetch indices of max element of the array

# %% [markdown]
# Store the values in a list

# %%
y_pred = ypred.argmax(axis=1)

# %%
y_pred[:5]
# Out:
# array([2, 2, 1, 2, 2], dtype=int64)

# %% [markdown]
# ### Plot X_test with label from our prediction

# %%
plt.figure(figsize=(12, 8))  

for i in range (20):

    plt.subplot(4,5,i+1)
    plt.imshow(xtest[i])
    if label[i]==0:
        plt.title('Glioma_tumor') 
    elif label[i]==1:
        plt.title('Meningioma_tumor')

    elif label[i]==1:
        plt.title('No_tumor')

    else:
        plt.title('Pituitary_tumor')
 
plt.tight_layout()

# %% [markdown]
# ### Visualise confusion matrix on a heatmap

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(ytest,y_pred)

# %% [markdown]
# ***

# %% [markdown]
# # <span style = "color:green;font-size:50px">Great Job!</span>
